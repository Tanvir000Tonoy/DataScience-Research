# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvir000Tonoy/Learning-Research/blob/main/Weekly-HomeWork/Week%204%20/Assignment_4_Matplotlib_and_Seaborn_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Upload the Gym data in google drive
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Home Tasks/Week04/gym_membership.csv')
df = pd.DataFrame(df)
# Display last 5 rows
print(f'\nLast 5 rows \n \n  {df.tail()}')
# Display Info
print(df.info())
# Check data types
print(f'\nData types \n \n {df.dtypes}')
# Out:
# Last 5 rows
#
#          id  gender    birthday  Age abonoment_type  visit_per_week  \
# 995   996  Female   9/22/1984   40       Standard               3
# 996   997  Female  11/19/2008   15       Standard               3
# 997   998    Male   10/5/1984   40       Standard               2
# 998   999    Male   2/22/2001   23       Standard               4
# 999  1000  Female    5/7/2006   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 995       Thu, Tue, Wed                False              NaN
# 996       Fri, Mon, Sun                 True     XCore, Zumba
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 995          20:56:00           22:42:00              106      False
# ...

# %%
# Task 1: Basic Matplotlib (3 plots)
# 1. Bar chart of gym membership types
# Use: gym['abonoment_type'].value_counts()
x = ['Standard','Premium']
y = df['abonoment_type'].value_counts()
plt.bar(x,y)
plt.title('Gym Membership Types')
plt.xlabel('Membership Type')
plt.ylabel('Count')
plt.show()

# 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])
plt.hist(df['avg_time_in_gym'])
plt.title('Time in Gym')
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()
# 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])
plt.scatter(df['Age'], df['visit_per_week'])
plt.title('Age vs Visits per Week')
plt.xlabel('Age')
plt.ylabel('Visits per Week')
plt.show()

# %%
# 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')
sns.boxplot(data=df, x='gender', y='Age')
plt.title('Gender vs Age')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()
# 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')
df['days_count'] = df['days_per_week'].apply(lambda x: len(str(x).split(',')))
sns.countplot(data=df, x='days_count')
plt.title('Gym Visits: Days per Week')
plt.xlabel('Days per Week')
plt.ylabel('Number of Members')
plt.show()

# 3. Bar plot: Average visits by membership type
# Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')
sns.barplot(data=df, x='abonoment_type', y='visit_per_week')
plt.title('Average Visits by Membership Type')
plt.xlabel('Membership Type')
plt.ylabel('Average Visits')
plt.show()
